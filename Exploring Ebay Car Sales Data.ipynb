# %% [markdown]
# # Exploring Ebay Car Sales Data
#
# ## Introduction
# The aim of this project is to clean the data and analyze the included used car listings from eBay Kleinanzeigen, a classifieds section of the German eBay website.The original dataset was scraped and uploaded to Kaggle by user orgesleka is no longer available, but you can now find it [here](https://data.world/data-society/used-cars-data)
#
# The data dictionary provided with data is as follows:
#
# - dateCrawled - When this ad was first crawled. All field-values are taken from this date.
# - name - Name of the car.
# - seller - Whether the seller is private or a dealer.
# - offerType - The type of listing
# - price - The price on the ad to sell the car.
# - abtest - Whether the listing is included in an A/B test.
# - vehicleType - The vehicle Type.
# - yearOfRegistration - The year in which the car was first registered.
# - gearbox - The transmission type.
# - powerPS - The power of the car in PS.
# - model - The car model name.
# - kilometer - How many kilometers the car has driven.
# - monthOfRegistration - The month in which the car was first registered.
# - fuelType - What type of fuel the car uses.
# - brand - The brand of the car.
# - notRepairedDamage - If the car has a damage which is not yet repaired.
# - dateCreated - The date on which the eBay listing was created.
# - nrOfPictures - The number of pictures in the ad.
# - postalCode - The postal code for the location of the vehicle.
# - lastSeenOnline - When the crawler saw this ad last online.

# %% [markdown]
# ## Opening and Exploring data
# Lets start by opening data set and continue with exploring the data.

# %%
# Import the pandas and NumPy libraries
import pandas as pd
import numpy as np

#Read the autos.csv CSV file into pandas
autos = pd.read_csv("/Users/sahithi/Documents/Python Projects/Exploring Ebay Car Sales Data/autos.csv", encoding='Latin-1')

# %%
autos
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0       privat   Angebot    480     test         NaN                1993
# 1       privat   Angebot  18300     test       coupe                2011
# 2       privat   Angebot   9800     test         suv                2004
# 3       privat   Angebot   1500     test  kleinwagen                2001
# 4       privat   Angebot   3600     test  kleinwagen                2008
# ...        ...       ...    ...      ...         ...                 ...
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# 0         manuell        0         golf     150000                    0
# 1         manuell      190          NaN     125000                    5
# 2       automatik      163        grand     125000                    8
# 3         manuell       75         golf     150000                    6
# 4         manuell       69        fabia      90000                    7
# ...           ...      ...          ...        ...                  ...
# 371523        NaN        0          NaN      20000                    1
# 371524  automatik      101       fortwo     125000                    3
# 371525    manuell      102  transporter     150000                    3
# 371526    manuell      100         golf     150000                    6
# 371527    manuell      320      m_reihe      50000                    8
#
#        fuelType           brand notRepairedDamage          dateCreated  \
# 0        benzin      volkswagen               NaN  2016-03-24 00:00:00
# 1        diesel            audi                ja  2016-03-24 00:00:00
# 2        diesel            jeep               NaN  2016-03-14 00:00:00
# 3        benzin      volkswagen              nein  2016-03-17 00:00:00
# 4        diesel           skoda              nein  2016-03-31 00:00:00
# ...         ...             ...               ...                  ...
# 371523      NaN  sonstige_autos               NaN  2016-03-14 00:00:00
# 371524   benzin           smart              nein  2016-03-05 00:00:00
# 371525   diesel      volkswagen              nein  2016-03-19 00:00:00
# 371526   diesel      volkswagen               NaN  2016-03-20 00:00:00
# 371527   benzin             bmw              nein  2016-03-07 00:00:00
#
#         nrOfPictures  postalCode             lastSeen
# 0                  0       70435  2016-04-07 03:16:57
# 1                  0       66954  2016-04-07 01:46:50
# 2                  0       90480  2016-04-05 12:47:46
# 3                  0       91074  2016-03-17 17:40:17
# 4                  0       60437  2016-04-06 10:17:21
# ...              ...         ...                  ...
# 371523             0       39576  2016-04-06 00:46:52
# 371524             0       26135  2016-03-11 18:17:12
# 371525             0       87439  2016-04-07 07:15:26
# 371526             0       40764  2016-03-24 12:45:21
# 371527             0       73326  2016-03-22 03:17:10
#
# [371528 rows x 20 columns]

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
#  15  notRepairedDamage    299468 non-null  object
#  16  dateCreated          371528 non-null  object
#  17  nrOfPictures         371528 non-null  int64
#  18  postalCode           371528 non-null  int64
#  19  lastSeen             371528 non-null  object
# dtypes: int64(7), object(13)
# memory usage: 56.7+ MB
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %% [markdown]
# ### Observations:
# Right away, we can see that the following columns have missing (null) values:
#
# - vehicleType
# - gearbox
# - model
# - fuelType
# - notRepairedDamage
#
# Also, it is worth noting that the columns are using camelcase instead of snakecase. Let us modify the columns to Python's preferred snakecase.

# %% [markdown]
# ## Column Renaming

# %%
# to print an array of the existing column names.
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
#modified new columns
new_columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'kilometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

# %%
# assigned new column names
autos.columns = new_columns
autos.head()
# Out:
#           date_crawled                            name  seller offer_type  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat    Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat    Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat    Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat    Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat    Angebot
#
#    price abtest vehicle_type  registration_year    gearbox  power_ps  model  \
# 0    480   test          NaN               1993    manuell         0   golf
# 1  18300   test        coupe               2011    manuell       190    NaN
# 2   9800   test          suv               2004  automatik       163  grand
# 3   1500   test   kleinwagen               2001    manuell        75   golf
# 4   3600   test   kleinwagen               2008    manuell        69  fabia
#
#    kilometer  registration_month fuel_type       brand unrepaired_damage  \
# 0     150000                   0    benzin  volkswagen               NaN
# 1     125000                   5    diesel        audi                ja
# 2     125000                   8    diesel        jeep               NaN
# 3     150000                   6    benzin  volkswagen              nein
# 4      90000                   7    diesel       skoda              nein
#
#             ad_created  nr_of_pictures  postal_code            last_seen
# 0  2016-03-24 00:00:00               0        70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00               0        66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00               0        90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00               0        91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00               0        60437  2016-04-06 10:17:21

# %% [markdown]
# After modifying the column headers, let us begin exploring the data set.
#
# Some things to look out for:
#
# Text columns where all or almost all values are the same. These can often be dropped as they don't have useful information for analysis.
# Examples of numeric data stored as text which can be cleaned and converted.
# Commonly used methods include:
#
# - describe() method
# - value_counts() method
# - isnull() method

# %%
autos.describe(include = 'all')
# Out:
#                date_crawled         name  seller offer_type         price  \
# count                371528       371528  371528     371528  3.715280e+05
# unique               280500       233531       2          2           NaN
# top     2016-03-24 14:49:47  Ford_Fiesta  privat    Angebot           NaN
# freq                      7          657  371525     371516           NaN
# mean                    NaN          NaN     NaN        NaN  1.729514e+04
# std                     NaN          NaN     NaN        NaN  3.587954e+06
# min                     NaN          NaN     NaN        NaN  0.000000e+00
# 25%                     NaN          NaN     NaN        NaN  1.150000e+03
# 50%                     NaN          NaN     NaN        NaN  2.950000e+03
# 75%                     NaN          NaN     NaN        NaN  7.200000e+03
# max                     NaN          NaN     NaN        NaN  2.147484e+09
#
#         abtest vehicle_type  registration_year  gearbox       power_ps  \
# count   371528       333659      371528.000000   351319  371528.000000
# unique       2            8                NaN        2            NaN
# top       test    limousine                NaN  manuell            NaN
# freq    192585        95894                NaN   274214            NaN
# mean       NaN          NaN        2004.577997      NaN     115.549477
# std        NaN          NaN          92.866598      NaN     192.139578
# min        NaN          NaN        1000.000000      NaN       0.000000
# 25%        NaN          NaN        1999.000000      NaN      70.000000
# 50%        NaN          NaN        2003.000000      NaN     105.000000
# 75%        NaN          NaN        2008.000000      NaN     150.000000
# max        NaN          NaN        9999.000000      NaN   20000.000000
#
#          model      kilometer  registration_month fuel_type       brand  \
# count   351044  371528.000000       371528.000000    338142      371528
# unique     251            NaN                 NaN         7          40
# top       golf            NaN                 NaN    benzin  volkswagen
# freq     30070            NaN                 NaN    223857       79640
# mean       NaN  125618.688228            5.734445       NaN         NaN
# std        NaN   40112.337051            3.712412       NaN         NaN
# min        NaN    5000.000000            0.000000       NaN         NaN
# 25%        NaN  125000.000000            3.000000       NaN         NaN
# 50%        NaN  150000.000000            6.000000       NaN         NaN
# 75%        NaN  150000.000000            9.000000       NaN         NaN
# max        NaN  150000.000000           12.000000       NaN         NaN
#
#        unrepaired_damage           ad_created  nr_of_pictures   postal_code  \
# count             299468               371528        371528.0  371528.00000
# unique                 2                  114             NaN           NaN
# top                 nein  2016-04-03 00:00:00             NaN           NaN
# freq              263182                14450             NaN           NaN
# mean                 NaN                  NaN             0.0   50820.66764
# std                  NaN                  NaN             0.0   25799.08247
# min                  NaN                  NaN             0.0    1067.00000
# 25%                  NaN                  NaN             0.0   30459.00000
# 50%                  NaN                  NaN             0.0   49610.00000
# 75%                  NaN                  NaN             0.0   71546.00000
# max                  NaN                  NaN             0.0   99998.00000
#
#                   last_seen
# count                371528
# unique               182806
# top     2016-04-07 06:45:59
# freq                     17
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %% [markdown]
# From the table above, we can conclude:
#
# . The seller and offer_type columns have only 2 unique values. Therefore, those columns contain virtually no useful information for analysis.
#
# . The nr_of_pictures column is irrelevant to us, as all rows present only the 0.0 value.

# %% [markdown]
# ## Deleting irrelevent columns
#
# ### seller, offer_type and nr_of_pictures

# %%
# drop the columns
autos.drop(columns=['seller', 'offer_type','nr_of_pictures'], inplace= True)

# %%
autos.shape
# Out:
# (371528, 17)

# %% [markdown]
# ## Describing numeric columns
# Now we can find out how many unique values numeric columns have. It is necessary to make sure that in many rows they have more than one value - otherwise these columns will be viewed as statistically insignificant and, consequently, will be removed from the dataframe

# %%
# Calculating the number of unique values for each numeric column
print('Unique values for numeric columns:')
print('price:', *autos['price'].unique().shape)
print('registration_year:', *autos['registration_year'].unique().shape)
print('kilometer:', *autos['kilometer'].unique().shape)
print('power_ps:', *autos['power_ps'].unique().shape)
print('registration_month:', *autos['registration_month'].unique().shape)
print('postal_code:', *autos['postal_code'].unique().shape)
# Out:
# Unique values for numeric columns:
# price: 5597
# registration_year: 155
# kilometer: 13
# power_ps: 794
# registration_month: 13
# postal_code: 8150

# %% [markdown]
# As we can see, all the four numeric columns have a plenty of unique values - that proves that they statistically significant and that they cannot be dropped

# %% [markdown]
# ## Data Exploration
#
# Before removing the outliers from 'kilometer' and 'price' columns, we need to describe these columns (with outliers included) in order to be able to compare them with themselves, but without outliers

# 330117  Jaguar_XJ220_Nur_1900_km_Deutsche_Auslieferung...      466000
# 155596                                 Porsche_911_GT3_RS      485000
# 337851                                        Porsche_911      487000
# 139405                Porsche_GT2_RS_/_limitierte_Auflage      488997
# 77185                            Aston_Martin_DB_7_Zagato      500000
# 119382                                      Porsche_911_R      500000
# 118058                           Audi__A6_allroad_quattro      517895
# 1846    BMW_M1_Museumsfahrzeug_Neuwagenzustand_Glossy_...      579000
# 136495               Mercedes_Benz_300_d_Cabriolet__W189_      585000
# 365461   BMW_M1_mit_4900_Km_Neuwagenzustand_Glossy_Orange      599000
# 161773                                 Porsche_Carrera_GT      600000
# 26327                                       Porsche_911_R      600000
# 137856  Porsche_911R_Der_letzte_Samurai!_Sauger__Schal...      619000
# 169098                                        Ferrari_206      650000
# 100851                                       Porsche_911R      700000
# 111647                        Lamborghini_Miura_S_Project      725000
# 118143            Porsche_911_R__500PS__6_Gang__limitiert      745000
# 344196                 Porsche_911R__991R__weiss/rot_2016      745000
# 163190                                    Ferrari_F12_TDF      780000
# 78265   McLaren_675LT_Spider/Delivery_on1._May/Vat_is_...      820000
# 194217  Volkswagen_Golf_Variant_1.8_Comfortline__Mit_K...      849000
# 85047                                         Porsche_911      911911
# 359083                                Volkswagen_Jetta_GT      999990
# 131785                              Suche_Autos_aller_Art      999999
# 332531  SUCHE_Chevrolet_oder_Gmc_pick_up_vor/bis_bj86_...      999999
# 38445                                       2_VW_Busse_T3      999999
# 118233  Liebhaber_sucht_Grand_Cherokee_5.9_LX__sofort_...      999999
# 69726                                        Oldtimer_Lkw      999999
# 312909                   Ford_Focus_Turnier_1.6_16V_Style      999999
# 159974                                        Manta_b_gsi      999999
# 301198                 4_Wochen_und_kein_Ergebnis!_Hilfe!      999999
# 155418                                   BMW_///_Bodensee      999999
# 169436                                  KAUFEN_JEDEN_AUTO      999999
# 141004                                  Kaufen_jeder_auto      999999
# 174617                                    BMW_523I_TAUSCH      999999
# 169656                                   BMW_///_Bodensee      999999
# 45833                             Porsche_911_Turbo__930_     1000000
# 312109                A3_zu_verkaufen_fuer_1.000.000_Euro     1000000
# 16889                    Ford_Mondeo_Kombi_TÜV_abgelaufen     1000000
# 306469                        Vw_Polo_86c_Schrott_Karosse     1000000
# 53507          Suzuki_SJ_Samurai_413_Van__Kein_Lada_Niva_     1000000
# 173279                                        12345678911     1010010
# 57594                                       Astra_f_teile     1111111
# 106651                      SUCHE_PKW_MIT_TÜV_MIN2_MONATE     1111111
# 167750                         Bmw_530d_zum_ausschlachten     1234566
# 20143                          Porsche_911R_Einer_von_911     1250000
# 78480                                       Porsche_991_R     1250000
# 316200                                        Ferrari_F40     1300000
# 367041                                      Maserati_MC12     1600000
# 333699                                      Maserati_MC12     1600000
# 45055   Ferrari_LaFerrari_Deutsche_Auslieferung._A_Cel...     2795000
# 41980                                       Maserati_MC12     2995000
# 364171                                        Ferrari_FXX     3890000
# 366861         Ferrari_FXX__unfallfrei__perfekter_Zustand     3895000
# 347435         Schlachte_Golf_4_1.4_16_fast_alles_noch_da     9999999
# 91106   Verkaufe_oder_tausche_wenn_nur_gegen_Kombi_s4_...     9999999
# 21467   Porsche_911_911R_1_of_20_ORIGINAL_R_nur_798KG!...     9999999
# 363434                     Vw_Passat_35i_1.8_schlachtfest    10000000
# 358868                     Tausche_BMW_E46_Touring_Diesel    10000000
# 121793                       Alter_VW_Kaefer_Scheunenfund    10000000
# 281833              Coole_Autowerkstatt_in_Esens_gesucht!    10000000
# 54295                        Mazda_5_2.0_CD_DPF_Exclusive    10000000
# 171824  suche_maserati_3200_gt_Zustand_unwichtig_laufe...    10000000
# 176070                                      Suche_BMW_Fun    10000000
# 196306                                Suche_Motorcross_.!    10000000
# 361451                                  Hilfe_Hilfe_Hilfe    10010011
# 318143                            Schlachte_Golf_3_gt_tdi    11111111
# 332028                     Golf_3_Gti_"16v_Turbo_vr6_bbs"    11111111
# 177744                     Suche_Trabant_auf_Ratenzahlung    11111111
# 185227                               Suche_fuer_mein_golf    11111111
# 127769                   Golf_4_laesst_sich_nicht_oeffnen    11111111
# 338415                         Polo_6n_gti__Zustand_egal_    11111111
# 54507                    Tausch_DKW_F8_gegen_Lanz_Bulldog    11111111
# 90853                               Verkaufe_oder_Tausche    11111111
# 210657   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000    11111111
# 14663                          Tausch_moeglich_Polo_vw_n9    11111111
# 287835                                 tausche_o_verkaufe    12345678
# 20746                                  Golf3_Schlachtfest    12345678
# 217547                                         Fiat_Punto    12345678
# 241847  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...    12345678
# 266124  Audi_A4_b7_8e_no_airride_static_20_Zoll_nur_Ta...    12345678
# 273145                                         Fiat_Punto    12345678
# 299872                          Vw_polo_6n_Colour_Concept    12345678
# 310924                     Wer_will_mich_kleinen_polo_6n1    12345678
# 39625                         Tausche_volvo_v40_gegen_van    12345678
# 279937  Mercedes_Benz_CLK_Coupe_280_7G_TRONIC_Sport_Av...    14000500
# 87799                                   Leasinguebernahme    27322222
# 183361  BMW_e60_nur_Tausch_prins_gasanlage_20_Zoll!_No...    32545461
# 120919                ???_?_???____???_?_???____???_?_???    74185296
# 251980   Audi_A6_2.7_TDI_quattro_S_Line_Luftfederung_Bose    99000000
# 150909                     Suche_Autos_Model_egal_welches    99999999
# 77520                         Tausch_gegen_gleichwertiges    99999999
# 366653      BMW_E36_Cabrio_tausch_gegen_ein_Opel_Insignia    99999999
# 362782        Passat_35i_1.8_90ps_Kombi_frisch_lackiert_!    99999999
# 127820                                   audi_a6_c5_avant    99999999
# 56973     tausche_ford_mondeo_mk3_ghia_gegen_anderes_auto    99999999
# 108987  Biete_Hier_zum_Tauschen_an_aber_nur_realistisc...    99999999
# 69747                    Suche_Mercedes_Benz_r_klasse_cdi    99999999
# 325589        Tausche/_verkaufe_Golf_1_LX_mit_H_Zulassung    99999999
# 160530                                     Golf_4_schrott    99999999
# 189737                         Oldtimer_Goggo_Transporter    99999999
# 280059  Kaufe_VW_Golf_1_auch_ohne_TÜV_________________...    99999999
# 268173                           Schlachte_e36_325i_Umbau    99999999
# 246635                          Suche_Vw_Passat..........    99999999
# 139052                Mercedes_Benz_CLS_350_CDI_7G_TRONIC    99999999
# 129969                            Kaufe_AUTOS_Zum_basteln  2147483647
#
#          abtest vehicle_type  registration_year    gearbox  power_ps  \
# 336623     test       cabrio               2010  automatik       625
# 168786     test        coupe               1984    manuell       340
# 195299  control        coupe               2010    manuell       620
# 328614     test       cabrio               2001    manuell       400
# 82700      test       cabrio               1972    manuell       194
# 303287     test        coupe               2010    manuell       620
# 10649   control        coupe               2004    manuell       483
# 360768  control        coupe               2015        NaN         0
# 201679     test       cabrio               1972    manuell       194
# 330117     test        coupe               1993    manuell       549
# 155596     test        coupe               2015  automatik       500
# 337851     test        coupe               2015  automatik       500
# 139405  control        coupe               2010    manuell       620
# 77185      test        coupe               2004    manuell       435
# 119382     test        coupe               2016    manuell       500
# 118058     test        kombi               2013  automatik       245
# 1846    control        coupe               1980    manuell       277
# 136495     test       cabrio               1960    manuell       160
# 365461  control        coupe               1980    manuell       377
# 161773  control       cabrio               2005    manuell       612
# 26327      test        coupe               2016    manuell       500
# 137856  control        coupe               2016    manuell       500
# 169098     test        coupe               1969    manuell       163
# 100851     test        coupe               2016        NaN         0
# 111647     test        coupe               1971    manuell       625
# 118143     test        coupe               2016    manuell       500
# 344196  control        coupe               2016    manuell       500
# 163190  control        coupe               2016  automatik       780
# 78265   control       cabrio               2016        NaN       674
# 194217     test        kombi               1998    manuell        75
# 85047      test       cabrio               1967    manuell       160
# 359083     test    limousine               1985    manuell       111
# 131785  control          NaN               2000        NaN         0
# 332531  control          NaN               1985        NaN         0
# 38445      test          bus               1981    manuell        70
# 118233     test          suv               1998  automatik       241
# 69726      test       andere               1960    manuell      9999
# 312909     test        kombi               2009    manuell       101
# 159974  control          NaN               1980        NaN       115
# 301198  control          NaN               2015        NaN         0
# 155418  control          NaN               1111        NaN         0
# 169436     test          NaN               2000        NaN         0
# 141004     test    limousine               2000        NaN       100
# 174617     test        kombi               1997    manuell       174
# 169656  control          NaN               9999        NaN         0
# 45833   control        coupe               1981    manuell       300
# 312109     test          NaN               2000        NaN         0
# 16889   control        kombi               1998        NaN         0
# 306469  control        coupe               1985    manuell        75
# 53507      test          suv               1992    manuell        69
# 173279  control          NaN               2017    manuell       101
# 57594      test          NaN               1995    manuell        71
# 106651  control          NaN               2000        NaN         0
# 167750  control        kombi               1999  automatik       190
# 20143      test        coupe               2016    manuell       500
# 78480      test        coupe               2016    manuell       500
# 316200  control        coupe               1992        NaN         0
# 367041     test        coupe               2005        NaN       625
# 333699     test        coupe               2005        NaN         0
# 45055   control        coupe               2016        NaN       963
# 41980   control        coupe               2005        NaN       630
# 364171     test        coupe               2006        NaN       799
# 366861     test        coupe               2006        NaN       799
# 347435     test          NaN               2000    manuell        75
# 91106      test    limousine               1996    manuell       380
# 21467   control        coupe               1967    manuell       215
# 363434     test        kombi               1996    manuell        90
# 358868  control        kombi               2002    manuell         0
# 121793  control          NaN               1910        NaN         0
# 281833     test          NaN               2019    manuell        10
# 54295   control          bus               2007    manuell       143
# 171824  control        coupe               1960    manuell       368
# 176070     test          NaN               1985  automatik       300
# 196306  control          NaN               2017    manuell         0
# 361451     test          NaN               2000        NaN         0
# 318143     test          NaN               1995        NaN         0
# 332028  control          NaN               1995        NaN       116
# 177744  control          NaN               1960        NaN         0
# 185227     test          NaN               2000        NaN         0
# 127769     test    limousine               2003    manuell        75
# 338415     test          NaN               2000        NaN       120
# 54507      test       andere               1953    manuell        20
# 90853   control          NaN               2018        NaN         0
# 210657     test    limousine               1973    manuell        48
# 14663   control        coupe               2003    manuell        64
# 287835     test        kombi               2001    manuell       101
# 20746      test          NaN               1995        NaN         0
# 217547     test   kleinwagen               2003    manuell        60
# 241847  control    limousine               2001    manuell       101
# 266124  control          NaN               2006        NaN         0
# 273145  control          NaN               2017        NaN        95
# 299872     test   kleinwagen               1996    manuell        60
# 310924     test   kleinwagen               1997    manuell        45
# 39625   control          NaN               2018    manuell        95
# 279937  control        coupe               2008  automatik       231
# 87799   control    limousine               2014    manuell       163
# 183361  control    limousine               2004  automatik       175
# 120919     test          NaN               2000        NaN         0
# 251980     test    limousine               2009  automatik       190
# 150909     test          NaN               1990        NaN         0
# 77520   control    limousine               1999  automatik       224
# 366653  control       cabrio               1996    manuell       192
# 362782     test          NaN               1995        NaN         0
# 127820     test        kombi               1999    manuell       165
# 56973   control    limousine               2002    manuell       131
# 108987     test          NaN               2017    manuell       110
# 69747   control          bus               2006        NaN         0
# 325589     test    limousine               1983    manuell        70
# 160530     test   kleinwagen               2001        NaN         0
# 189737  control   kleinwagen               1956    manuell        15
# 280059  control       andere               1974    manuell         0
# 268173     test        coupe               1992        NaN       240
# 246635     test          NaN               2000        NaN         0
# 139052  control        coupe               2009  automatik       224
# 129969     test       andere               1996    manuell       888
#
#               model  kilometer  registration_month fuel_type           brand  \
# 336623       andere      30000                   3    benzin   mercedes_benz
# 168786          NaN      20000                   8    benzin  sonstige_autos
# 195299          911      20000                  12    benzin         porsche
# 328614      z_reihe       5000                   4    benzin             bmw
# 82700           NaN     100000                   1    benzin  sonstige_autos
# 303287          911      20000                  10    benzin         porsche
# 10649           911      50000                   4    benzin         porsche
# 360768          NaN       5000                   8       NaN  sonstige_autos
# 201679          NaN     100000                   1    benzin  sonstige_autos
# 330117       andere       5000                   5    benzin          jaguar
# 155596          911       5000                   8    benzin         porsche
# 337851          NaN       5000                   8       NaN         porsche
# 139405          911      20000                  11    benzin         porsche
# 77185           NaN      30000                   7    benzin  sonstige_autos
# 119382          911       5000                   2    benzin         porsche
# 118058       andere      40000                   1    diesel            audi
# 1846         andere      20000                  12    benzin             bmw
# 136495       andere       5000                   7    benzin   mercedes_benz
# 365461       andere       5000                   3    benzin             bmw
# 161773       andere      10000                   4    benzin         porsche
# 26327           911       5000                   3    benzin         porsche
# 137856          911       5000                   3    benzin         porsche
# 169098          NaN      90000                   1    benzin  sonstige_autos
# 100851          911       5000                   3       NaN         porsche
# 111647          NaN       5000                   4    benzin  sonstige_autos
# 118143          911       5000                   3    benzin         porsche
# 344196          911       5000                   3    benzin         porsche
# 163190          NaN       5000                   3    benzin  sonstige_autos
# 78265           NaN       5000                   3    benzin  sonstige_autos
# 194217         golf     150000                   1    benzin      volkswagen
# 85047           911       5000                  12    benzin         porsche
# 359083        jetta     150000                  12    benzin      volkswagen
# 131785          NaN     100000                   0       NaN  sonstige_autos
# 332531          NaN     150000                   0    diesel       chevrolet
# 38445   transporter     150000                   1    benzin      volkswagen
# 118233        grand     150000                   1    benzin            jeep
# 69726           NaN     150000                   0       NaN   mercedes_benz
# 312909        focus     125000                   4    benzin            ford
# 159974       andere      50000                   0       NaN            opel
# 301198          NaN       5000                   2       NaN  sonstige_autos
# 155418          NaN       5000                   0       NaN             bmw
# 169436           a5     100000                   2       NaN            audi
# 141004          NaN     150000                   5    diesel             bmw
# 174617          5er     150000                  11       NaN             bmw
# 169656          NaN      10000                   0       NaN             bmw
# 45833           911     150000                   1    benzin         porsche
# 312109           a3     150000                   0       NaN            audi
# 16889        mondeo     150000                   0    benzin            ford
# 306469         polo     150000                   0    benzin      volkswagen
# 53507        andere     100000                   0    benzin          suzuki
# 173279       zafira     150000                   9    diesel            opel
# 57594         astra     150000                   5    benzin            opel
# 106651          NaN     150000                   0       NaN  sonstige_autos
# 167750          NaN     150000                   2    diesel             bmw
# 20143           911       5000                   3    benzin         porsche
# 78480           911       5000                   3    benzin         porsche
# 316200          NaN      50000                  12       NaN  sonstige_autos
# 367041          NaN      10000                   4    benzin  sonstige_autos
# 333699          NaN      10000                   4       NaN  sonstige_autos
# 45055           NaN       5000                   3       NaN  sonstige_autos
# 41980           NaN       5000                   7    benzin  sonstige_autos
# 364171          NaN       5000                   7       NaN  sonstige_autos
# 366861          NaN       5000                   4    benzin  sonstige_autos
# 347435         golf     150000                   0    benzin      volkswagen
# 91106            a4      60000                   5    benzin            audi
# 21467           911      50000                  10    benzin         porsche
# 363434          NaN     150000                   0    benzin      volkswagen
# 358868          NaN     150000                   7    diesel             bmw
# 121793       kaefer     100000                   0       NaN      volkswagen
# 281833          NaN       5000                   0       NaN  sonstige_autos
# 54295       5_reihe     150000                   2    diesel           mazda
# 171824          NaN     100000                   1    benzin  sonstige_autos
# 176070          NaN     150000                   0       NaN             bmw
# 196306         golf       5000                   0    benzin      volkswagen
# 361451          NaN     150000                   0       NaN  sonstige_autos
# 318143          NaN     150000                   0       NaN      volkswagen
# 332028         golf     150000                   6    benzin      volkswagen
# 177744          NaN     150000                   0       NaN         trabant
# 185227          NaN       5000                   0       NaN      volkswagen
# 127769         golf     125000                   9    benzin      volkswagen
# 338415         polo     125000                   0    benzin      volkswagen
# 54507           NaN     150000                   5       NaN            audi
# 90853           NaN     150000                   0       NaN             bmw
# 210657       escort      50000                   3    benzin            ford
# 14663          polo     150000                   2    benzin      volkswagen
# 287835        focus     150000                   0    benzin            ford
# 20746           NaN     150000                   0       NaN      volkswagen
# 217547        punto      80000                   0       NaN            fiat
# 241847       vectra     150000                   3    benzin            opel
# 266124           a4     150000                   0       NaN            audi
# 273145        punto     150000                   0       NaN            fiat
# 299872         polo     150000                   0       NaN      volkswagen
# 310924          NaN     150000                   7    benzin      volkswagen
# 39625           v40     150000                   6       NaN           volvo
# 279937          clk     125000                   5    benzin   mercedes_benz
# 87799            c4      40000                   2    diesel         citroen
# 183361          5er       5000                  10       lpg             bmw
# 185227  2016-04-05 23:16:23
# 127769  2016-03-30 03:18:00
# 338415  2016-04-06 15:45:52
# 54507   2016-04-05 14:46:32
# 90853   2016-04-05 02:46:37
# 210657  2016-03-12 22:45:27
# 14663   2016-04-07 10:16:51
# 287835  2016-04-01 21:18:10
# 20746   2016-03-17 16:15:43
# 217547  2016-03-11 23:17:24
# 241847  2016-03-31 18:56:54
# 266124  2016-04-06 08:16:46
# 273145  2016-03-09 15:45:47
# 299872  2016-04-06 21:17:11
# 310924  2016-04-07 08:16:29
# 39625   2016-04-06 23:17:31
# 279937  2016-04-03 11:56:00
# 87799   2016-03-08 20:39:05
# 183361  2016-03-28 00:18:31
# 120919  2016-03-25 12:43:02
# 251980  2016-03-25 04:45:53
# 150909  2016-04-02 22:41:54
# 77520   2016-04-06 05:15:30
# 366653  2016-03-20 10:59:52
# 362782  2016-03-20 08:18:07
# 127820  2016-03-14 17:49:54
# 56973   2016-03-18 18:52:27
# 108987  2016-04-05 14:16:25
# 69747   2016-04-06 07:45:57
# 325589  2016-04-05 21:44:41
# 160530  2016-03-29 12:58:27
# 189737  2016-04-03 12:41:33
# 280059  2016-03-24 16:15:27
# 268173  2016-04-07 05:46:52
# 246635  2016-04-02 15:15:54
# 139052  2016-03-14 22:40:52
# 129969  2016-03-20 11:45:35

# %% [markdown]
# ### Removing outliers from 'price'

# %%
# Removing the outliers from the 'price' column
autos = autos[(((autos['price'] >= 1) & (autos['price'] <= 350000 )) | ((autos["name"] == 'Ferrari' ) & (autos["name"] == 'Maserati')))]

autos['price'].value_counts().sort_index()
# Out:
# 1        922
# 2          6
# 3          6
# 5         19
# 7          1
#         ...
# 16199      6
# 16200     65
# 16215      1
# 16250     28
# 16270      1
# Name: price, Length: 2989, dtype: int64

# %% [markdown]
# ### kilometer

# %%
# See how many unique values are in the column

autos['kilometer'].unique().shape
# Out:
# (4,)

# %%
autos['kilometer'].describe()
# Out:
# count    286642.000000
# mean     142345.504148
# std       16467.169306
# min       90000.000000
# 25%      150000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: kilometer, dtype: float64

# %%
autos['kilometer'].value_counts()
# Out:
# 150000    227618
# 125000     34564
# 100000     13760
# 90000      10700
# Name: kilometer, dtype: int64

# %% [markdown]
# The odometer_km column seems to have no major issues:
#
# The min value is 90000 km, present in 10700 entries.
# The max value is 150000 km, which is also the most frequent value, occuring in 227618 entries.
# The mean is 142345.5 km, with a standard deviation of 16467.1 km.
# Most entries have a value superior to 900000 km. Since we are working with used cars, this seems reasonable. Therefore, we will not remove any entries based on unrealistically high or low kilometer values.

# %% [markdown]
# ### Comparing the columns with and without outliers
# Now we can compare the values of the columns with outliers included with the values of the same columns without outliers:

# %%
# Printing the table with outliers
outliers_table
# Out:
#            kilometer         price
# count  371528.000000  3.715280e+05
# mean   125618.688228  1.729514e+04
# std     40112.337051  3.587954e+06
# min      5000.000000  0.000000e+00
# 25%    125000.000000  1.150000e+03
# 50%    150000.000000  2.950000e+03
# 75%    150000.000000  7.200000e+03
# max    150000.000000  2.147484e+09

# %%
# Observing the values left in 'kilometer' and 'price' after removing outliers
autos[['kilometer', 'price']].describe()
# Out:
#            kilometer          price
# count  295620.000000  295620.000000
# mean   142410.594682    3563.428415
# std     16413.471333    3532.760660
# min     90000.000000       0.000000
# 25%    150000.000000     999.000000
# 50%    150000.000000    2300.000000
# 75%    150000.000000    4999.000000
# max    150000.000000   16270.000000

# %% [markdown]
# After the outliers were removed, 'kilometer' has experienced some changes. Its smallest values were outliers and their removal, consequently lead to smaller standard deviation (16413 instead of 40112) and bigger minimum value (90000 instead of 5000).
#
# The new 'price' column has changed significantly as well: its standard deviation is now equal to 3532 instead of 3587; its maximum value is now 16270 instead of 2.147484e+09

# %% [markdown]
# ### Registaration year

# %%
# see how many unique values
autos['registration_year'].unique().shape
# Out:
# (89,)

# %%
autos['registration_year'].describe()
# Out:
# count    286642.000000
# mean       2002.539391
# std           7.311772
# min        1000.000000
# 25%        1999.000000
# 50%        2002.000000
# 75%        2006.000000
# max        3000.000000
# Name: registration_year, dtype: float64

# %%
autos['registration_year'].value_counts().sort_index()
# Out:
# 1000        1
# 1400        1
# 1600        1
# 1910       24
# 1928        1
# 1930        1
# 1931        1
# 1932        1
# 1934        1
# 1936        1
# 1937        1
# 1938        1
# 1940        1
# 1941        1
# 1942        2
# 1943        1
# 1945        2
# 1946        1
# 1950        8
# 1951        3
# 1952        3
# 1953        9
# 1954        4
# 1955        4
# 1956        6
# 1957        8
# 1958        7
# 1959       10
# 1960       50
# 1961        8
# 1962       18
# 1963       19
# 1964       20
# 1965       40
# 1966       50
# 1967       41
# 1968       46
# 1969       58
# 1970      133
# 1971       77
# 1972       95
# 1973       86
# 1974       85
# 1975       60
# 1976       75
# 1977      102
# 1978      158
# 1979      181
# 1980      294
# 1981      170
# 1982      211
# 1983      293
# 1984      272
# 1985      478
# 1986      369
# 1987      507
# 1988      757
# 1989     1025
# 1990     2041
# 1991     2370
# 1992     2610
# 1993     3023
# 1994     4355
# 1995     8258
# 1996     9770
# 1997    13314
# 1998    16293
# 1999    21012
# 2000    21555
# 2001    18589
# 2002    17669
# 2003    18346
# 2004    18031
# 2005    19525
# 2006    17316
# 2007    14307
# 2008    11722
# 2009     9071
# 2010     5567
# 2011     3863
# 2012     1592
# 2013      331
# 2014       51
# 2015       36
# 2016     8053
# 2017     8778
# 2018     3298
# 2019       12
# 3000        1
# Name: registration_year, dtype: int64

# %% [markdown]
# Since the car couldn't be registered before 1900 and after 2016 which is year where this listings were added we will remove this outliers.

# %%
autos = autos[autos['registration_year'].between(1900,2019)]

# %%
autos['registration_year'].value_counts().sort_index()
# Out:
# 1910       24
# 1928        1
# 1930        1
# 1931        1
# 1932        1
# 1934        1
# 1936        1
# 1937        1
# 1938        1
# 1940        1
# 1941        1
# 1942        2
# 1943        1
# 1945        2
# 1946        1
# 1950        8
# 1951        3
# 1952        3
# 1953        9
# 1954        4
# 1955        4
# 1956        6
# 1957        8
# 1958        7
# 1959       10
# 1960       50
# 1961        8
# 1962       18
# 1963       19
# 1964       20
# 1965       40
# 1966       50
# 1967       41
# 1968       46
# 1969       58
# 1970      133
# 1971       77
# 1972       95
# 1973       86
# 1974       85
# 1975       60
# 1976       75
# 1977      102
# 1978      158
# 1979      181
# 1980      294
# 1981      170
# 1982      211
# 1983      293
# 1984      272
# 1985      478
# 1986      369
# 1987      507
# 1988      757
# 1989     1025
# 1990     2041
# 1991     2370
# 1992     2610
# 1993     3023
# 1994     4355
# 1995     8258
# 1996     9770
# 1997    13314
# 1998    16293
# 1999    21012
# 2000    21555
# 2001    18589
# 2002    17669
# 2003    18346
# 2004    18031
# 2005    19525
# 2006    17316
# 2007    14307
# 2008    11722
# 2009     9071
# 2010     5567
# 2011     3863
# 2012     1592
# 2013      331
# 2014       51
# 2015       36
# 2016     8053
# Name: registration_year, dtype: int64

# %% [markdown]
# ## Date values
#
# There are 5 columns that should represent date values, the date_crawled, last_seen, and ad_created columns are all identified as string values by pandas. Because these three columns are represented as strings, we need to convert the data into a astype datetime representation so we can understand it quantitatively. The other two registration_month and registration_year columns are represented as numeric values, so we can use methods like Series.describe() to understand the distribution without any extra data processing.

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-24 11:52:17  2016-03-24 00:00:00  2016-04-07 03:16:57
# 2  2016-03-14 12:52:21  2016-03-14 00:00:00  2016-04-05 12:47:46
# 3  2016-03-17 16:54:04  2016-03-17 00:00:00  2016-03-17 17:40:17
# 4  2016-03-31 17:25:20  2016-03-31 00:00:00  2016-04-06 10:17:21
# 5  2016-04-04 17:36:23  2016-04-04 00:00:00  2016-04-06 19:17:07

# %% [markdown]
# We can see that the date is in a format YYYY-MM-DD HH-MM-SS. We are going to use pd.to_datetime to change astype to datetime and we will change format to YYYY-MM-DD.

# %% [markdown]
# ### date_crawled

# %%
# change dtype to datetime
autos['date_crawled'] = pd.to_datetime(autos['date_crawled'], format = "%Y-%m-%d %H:%M:%S")
# change format to YYYY-MM-DD
date_crawled = autos['date_crawled'].dt.strftime('%Y-%m-%d')

# %%
date_crawled.value_counts(normalize = True, dropna = False)
# Out:
# 2016-04-03    0.038135
# 2016-04-04    0.037437
# 2016-03-14    0.036492
# 2016-03-12    0.036248
# 2016-03-21    0.036066
# 2016-03-20    0.036052
# 2016-03-07    0.035690
# 2016-03-19    0.035257
# 2016-03-28    0.034967
# 2016-04-02    0.034538
# 2016-03-09    0.034252
# 2016-03-29    0.034012
# 2016-04-01    0.033959
# 2016-03-08    0.033823
# 2016-03-30    0.033621
# 2016-03-15    0.033617
# 2016-03-10    0.033122
# 2016-03-22    0.033059
# 2016-03-11    0.032951
# 2016-03-25    0.032616
# 2016-03-17    0.032142
# 2016-03-23    0.032128
# 2016-03-26    0.031744
# 2016-03-31    0.031695
# 2016-03-16    0.030373
# 2016-03-27    0.030080
# 2016-03-24    0.029884
# 2016-03-05    0.025468
# 2016-03-13    0.015420
# 2016-03-06    0.014367
# 2016-03-18    0.013306
# 2016-04-05    0.012744
# 2016-04-06    0.003157
# 2016-04-07    0.001577
# Name: date_crawled, dtype: float64

# %% [markdown]
# ### 7.2 ad_created

# %%
# change dtype to datetime
autos['ad_created'] = pd.to_datetime(autos['ad_created'], format = "%Y-%m-%d %H:%M:%S")
# change format to YYYY-MM-DD
ad_created = autos['ad_created'].dt.strftime('%Y-%m')

# %%
ad_created.value_counts(normalize = True, dropna = False)
# Out:
# 2016-03    0.838399
# 2016-04    0.160370
# 2016-02    0.001022
# 2016-01    0.000150
# 2015-12    0.000024
# 2015-11    0.000017
# 2015-09    0.000007
# 2015-08    0.000003
# 2014-03    0.000003
# 2015-03    0.000003
# Name: ad_created, dtype: float64

# %% [markdown]
# The eBay listings were created between March 2014 and April 2016. But 99% of the ads were created in March and April 2016. Most adds were created in March 2016 - 83.8%

# %% [markdown]
# ### last_seen

# %%
# change dtype to datetime
autos['last_seen'] = pd.to_datetime(autos['last_seen'], format = "%Y-%m-%d %H:%M:%S")
# change format to YYYY-MM-DD
last_seen= autos['last_seen'].dt.strftime('%Y-%m-%d')

# %%
last_seen.value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2016-03-05    0.001399
# 2016-03-06    0.004410
# 2016-03-07    0.005701
# 2016-03-08    0.008676
# 2016-03-09    0.010512
# 2016-03-10    0.012211
# 2016-03-11    0.013766
# 2016-03-12    0.024990
# 2016-03-13    0.008928
# 2016-03-14    0.012891
# 2016-03-15    0.017294
# 2016-03-16    0.017398
# 2016-03-17    0.030551
# 2016-03-18    0.007333
# 2016-03-19    0.017468
# 2016-03-20    0.021194
# 2016-03-21    0.021288
# 2016-03-22    0.021571
# 2016-03-23    0.018703
# 2016-03-24    0.020259
# 2016-03-25    0.020064
# 2016-03-26    0.016823
# 2016-03-27    0.017656
# 2016-03-28    0.023434
# 2016-03-29    0.024302
# 2016-03-30    0.024442
# 2016-03-31    0.024896
# 2016-04-01    0.024784
# 2016-04-02    0.026008
# 2016-04-03    0.026301
# 2016-04-04    0.026033
# 2016-04-05    0.120978
# 2016-04-06    0.205475
# 2016-04-07    0.122262
# Name: last_seen, dtype: float64

# %% [markdown]
# The crawler saw this ads between 5th of March and 7th of April 2016

# %% [markdown]
# ## Translate to English
#
# We will translate data from this columns: vehicle_type, gearbox, model, fuel_type, brand and unrepaired_damage from german to english. First we will check unique values for every column, translate them and than map the values to their english counterparts.

# %% [markdown]
# ### vehicle_type

# %%
vehicle_type = pd.unique(autos['vehicle_type'])

# %%
vehicle_type
# Out:
# array([nan, 'suv', 'kleinwagen', 'limousine', 'cabrio', 'kombi', 'bus',
#        'coupe', 'andere'], dtype=object)

# %%
new_vt = ['limousine', 'small_car', 'combi', 'bus', 'convertible', 'coupe', 'suv', 'other']

# %%
vehicle_type = new_vt

# %%
vehicle_type
# Out:
# ['limousine',
#  'small_car',
#  'combi',
#  'bus',
#  'convertible',
#  'coupe',
#  'suv',
#  'other']

# %% [markdown]
# ### gearbox

# %%
gearbox = pd.unique(autos['gearbox'])

# %%
gearbox
# Out:
# array(['manuell', 'automatik', nan], dtype=object)

# %%
new_gearbox = ['manual', 'automatic', 'nan']

# %%
gearbox=new_gearbox

# %%
gearbox
# Out:
# ['manual', 'automatic', 'nan']

# %% [markdown]
# ### fuel_type

# %%
fuel_type = pd.unique(autos['fuel_type'])

# %%
fuel_type
# Out:
# array(['benzin', 'diesel', nan, 'lpg', 'andere', 'hybrid', 'cng',
#        'elektro'], dtype=object)

# %%
new_ft = ['petrol', 'diesel', 'lpg', 'cng', 'hybrid', 'electric', 'other']

# %%
fuel_type = new_ft

# %%
fuel_type
# Out:
# ['petrol', 'diesel', 'lpg', 'cng', 'hybrid', 'electric', 'other']

# %% [markdown]
# ### unrepaired_damage

# %%
unrepaired_damage = pd.unique(autos['unrepaired_damage'])

# %%
unrepaired_damage
# Out:
# array([nan, 'nein', 'ja'], dtype=object)

# %%
new_urd = ['nan', 'no', 'yes']

# %%
unrepaired_damage = new_urd

# %%
unrepaired_damage
# Out:
# ['nan', 'no', 'yes']

# %% [markdown]
# ### model

# %%
print(pd.unique(autos['model']))
# Out:
# ['golf' 'grand' 'fabia' '3er' '2_reihe' '3_reihe' 'passat' 'polo' 'twingo'
#  'c_max' 'a_klasse' 'scirocco' '5er' 'meriva' 'arosa' 'andere' 'c4'
#  'punto' 'e_klasse' 'clio' 'kangoo' 'one' '1er' 'b_klasse' 'signum'
#  'astra' nan 'a8' 'jetta' 'fiesta' 'c_klasse' 'vito' 'sprinter' '156'
#  'escort' 'forester' 'xc_reihe' 'scenic' 'a4' 'ka' 'insignia'
#  'transporter' 'combo' 'focus' 'tt' 'civic' 'corsa' 'a6' 'jazz' 'omega'
#  'slk' '7er' '80' '147' '100' 'z_reihe' 'sportage' 'v40' 'touran' 'getz'
#  'a3' 'almera' 'megane' 'fortwo' 'lupo' 'r19' 'zafira' 'caddy' 'mondeo'
#  'cordoba' 'impreza' 'a1' 'vectra' 'tiguan' 'i_reihe' 'espace' 'sharan'
#  'panda' 'ceed' 'ibiza' 'octavia' 'rx_reihe' 'modus' 'matiz' 'beetle'
#  'touareg' 'logan' '6_reihe' 'spider' 'cuore' 's_max' 'a2' 'c3' 's_klasse'
#  '1_reihe' 'eos' 'avensis' 'viano' 'sl' 'kaefer' 'santa' 'fox' 'cooper'
#  'leon' 'laguna' 'ptcruiser' 'clk' 'primera' '4_reihe' 'galaxy' 'x_reihe'
#  'micra' '159' 'qashqai' 'carisma' 'accord' 'corolla' 'lanos' 'phaeton'
#  'verso' 'colt' 'swift' 'boxster' 'stilo' 'berlingo' 'alhambra' 'mx_reihe'
#  'transit' 'roadster' 'ypsilon' 'galant' 'justy' '90' 'sirion' 'agila'
#  'sorento' 'cr_reihe' 'v50' 'c_reihe' 'v_klasse' 'm_klasse' 'yaris' 'c5'
#  'seicento' 'cc' 'carnival' 'fusion' 'bora' 'forfour' 'duster' 'cl'
#  'tigra' '300c' 'a5' 'kuga' '5_reihe' 'x_type' 'ducato' 's_type' 'rav'
#  'x_trail' 'toledo' 'altea' 'rio' 'voyager' 'calibra' 'v70' 'picanto'
#  'antara' 'tucson' 'c1' 'wrangler' 'lybra' 'q7' 'lancer' 'captiva'
#  'roomster' 'c2' 'discovery' 'freelander' 'aygo' 'note' 'kadett' 'navara'
#  '900' 'cherokee' 'samara' 'defender' 'cx_reihe' 'legacy' 'pajero' 'auris'
#  'cayenne' 'niva' '500' 'exeo' 's60' 'clubman' 'm_reihe' 'nubira' 'vivaro'
#  'g_klasse' 'jimny' 'superb' '850' 'range_rover' 'yeti' 'serie_2' 'bravo'
#  '911' 'outlander' 'doblo' 'sandero' '6er' 'move' 'musa' '9000' 'kalos'
#  'v60' '145' 'aveo' 'croma' 'glk' '200' 'up' 'mustang' 'range_rover_sport'
#  'juke' '601' 'crossfire' 'charade' 'rangerover' 'range_rover_evoque'
#  'materia' 'delta' 'spark' 'terios' 'amarok' 'elefantino' 'b_max' 'i3'
#  'q5' 'lodgy' 'kappa' 'kalina' 'gl' 'mii' 'serie_3' 'q3']

# %% [markdown]
# Since we have alot unique values, we will translate only andere to other.

# %%
autos['model'] = autos['model'].str.replace('andere', 'other')
print(pd.unique(autos['model']))
# Out:
# ['golf' 'grand' 'fabia' '3er' '2_reihe' '3_reihe' 'passat' 'polo' 'twingo'
#  'c_max' 'a_klasse' 'scirocco' '5er' 'meriva' 'arosa' 'other' 'c4' 'punto'
#  'e_klasse' 'clio' 'kangoo' 'one' '1er' 'b_klasse' 'signum' 'astra' nan
#  'a8' 'jetta' 'fiesta' 'c_klasse' 'vito' 'sprinter' '156' 'escort'
#  'forester' 'xc_reihe' 'scenic' 'a4' 'ka' 'insignia' 'transporter' 'combo'
#  'focus' 'tt' 'civic' 'corsa' 'a6' 'jazz' 'omega' 'slk' '7er' '80' '147'
#  '100' 'z_reihe' 'sportage' 'v40' 'touran' 'getz' 'a3' 'almera' 'megane'
#  'fortwo' 'lupo' 'r19' 'zafira' 'caddy' 'mondeo' 'cordoba' 'impreza' 'a1'
#  'vectra' 'tiguan' 'i_reihe' 'espace' 'sharan' 'panda' 'ceed' 'ibiza'
#  'octavia' 'rx_reihe' 'modus' 'matiz' 'beetle' 'touareg' 'logan' '6_reihe'
#  'spider' 'cuore' 's_max' 'a2' 'c3' 's_klasse' '1_reihe' 'eos' 'avensis'
#  'viano' 'sl' 'kaefer' 'santa' 'fox' 'cooper' 'leon' 'laguna' 'ptcruiser'
#  'clk' 'primera' '4_reihe' 'galaxy' 'x_reihe' 'micra' '159' 'qashqai'
#  'carisma' 'accord' 'corolla' 'lanos' 'phaeton' 'verso' 'colt' 'swift'
#  'boxster' 'stilo' 'berlingo' 'alhambra' 'mx_reihe' 'transit' 'roadster'
#  'ypsilon' 'galant' 'justy' '90' 'sirion' 'agila' 'sorento' 'cr_reihe'
#  'v50' 'c_reihe' 'v_klasse' 'm_klasse' 'yaris' 'c5' 'seicento' 'cc'
#  'carnival' 'fusion' 'bora' 'forfour' 'duster' 'cl' 'tigra' '300c' 'a5'
#  'kuga' '5_reihe' 'x_type' 'ducato' 's_type' 'rav' 'x_trail' 'toledo'
#  'altea' 'rio' 'voyager' 'calibra' 'v70' 'picanto' 'antara' 'tucson' 'c1'
#  'wrangler' 'lybra' 'q7' 'lancer' 'captiva' 'roomster' 'c2' 'discovery'
#  'freelander' 'aygo' 'note' 'kadett' 'navara' '900' 'cherokee' 'samara'
#  'defender' 'cx_reihe' 'legacy' 'pajero' 'auris' 'cayenne' 'niva' '500'
#  'exeo' 's60' 'clubman' 'm_reihe' 'nubira' 'vivaro' 'g_klasse' 'jimny'
#  'superb' '850' 'range_rover' 'yeti' 'serie_2' 'bravo' '911' 'outlander'
#  'doblo' 'sandero' '6er' 'move' 'musa' '9000' 'kalos' 'v60' '145' 'aveo'
#  'croma' 'glk' '200' 'up' 'mustang' 'range_rover_sport' 'juke' '601'
#  'crossfire' 'charade' 'rangerover' 'range_rover_evoque' 'materia' 'delta'
#  'spark' 'terios' 'amarok' 'elefantino' 'b_max' 'i3' 'q5' 'lodgy' 'kappa'
#  'kalina' 'gl' 'mii' 'serie_3' 'q3']

# %% [markdown]
# ### brand

# %%
print(pd.unique(autos['brand']))
# Out:
# ['volkswagen' 'jeep' 'skoda' 'bmw' 'peugeot' 'mazda' 'renault' 'ford'
#  'mercedes_benz' 'opel' 'seat' 'citroen' 'fiat' 'mini' 'sonstige_autos'
#  'audi' 'honda' 'alfa_romeo' 'subaru' 'volvo' 'mitsubishi' 'kia' 'hyundai'
#  'nissan' 'smart' 'suzuki' 'lancia' 'toyota' 'chevrolet' 'dacia'
#  'daihatsu' 'trabant' 'chrysler' 'jaguar' 'daewoo' 'porsche' 'rover'
#  'saab' 'land_rover' 'lada']

# %%
autos['brand'] = autos['brand'].str.replace('sonstige_autos', 'other')
print(pd.unique(autos['brand']))
# Out:
# ['volkswagen' 'jeep' 'skoda' 'bmw' 'peugeot' 'mazda' 'renault' 'ford'
#  'mercedes_benz' 'opel' 'seat' 'citroen' 'fiat' 'mini' 'other' 'audi'
#  'honda' 'alfa_romeo' 'subaru' 'volvo' 'mitsubishi' 'kia' 'hyundai'
#  'nissan' 'smart' 'suzuki' 'lancia' 'toyota' 'chevrolet' 'dacia'
#  'daihatsu' 'trabant' 'chrysler' 'jaguar' 'daewoo' 'porsche' 'rover'
#  'saab' 'land_rover' 'lada']

# %% [markdown]
# ## Analyze data
#
# ### Mean price by brand.
#
# First we will calculate the mean price for every brand. We can use aggregation to understand the brand column.

# %%
autos['brand'].value_counts().sort_index
# Out:
# <bound method Series.sort_index of volkswagen       60625
# opel             31649
# bmw              30816
# mercedes_benz    26319
# audi             23958
# ford             19291
# renault          14085
# peugeot           8598
# fiat              6750
# seat              5029
# mazda             4443
# skoda             3913
# citroen           3781
# nissan            3645
# toyota            3353
# smart             3055
# volvo             2806
# mitsubishi        2386
# hyundai           2206
# honda             2147
# alfa_romeo        1872
# mini              1789
# kia               1609
# suzuki            1489
# other             1459
# chrysler          1189
# chevrolet         1001
# subaru             605
# daihatsu           596
# jeep               533
# porsche            476
# saab               475
# daewoo             430
# land_rover         423
# jaguar             411
# dacia              404
# rover              397
# lancia             372
# trabant             95
# lada                70
# Name: brand, dtype: int64>

# %% [markdown]
# We have 40 diffrent car brands in our data. The most popular brand is Volkswagen. We will continue to analyze only for the 10 most popular brands.

# %%
#names of Top10 brands
top10 = autos['brand'].value_counts().index[:10]

# %%
top10
# Out:
# Index(['volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat'],
#       dtype='object')

# %%
# create a dictionary
mean_price = {}
for brand in top10:
    selected_rows = autos[autos['brand']== brand]
    price = selected_rows['price'].mean()
    mean_price[brand] = int(price)
    
mean_price = pd.Series(mean_price).sort_values(ascending=False)

# %%
brand_price = pd.DataFrame(mean_price, columns =['mean_price'])
brand_price
# Out:
#                mean_price
# bmw                  5526
# audi                 5365
# mercedes_benz        5062
# volkswagen           3670
# seat                 2929
# ford                 2500
# peugeot              2479
# opel                 2237
# fiat                 1939
# renault              1820

# %% [markdown]
# We can see that in the top 10 brands, there's a distinct price gap.
#
# - Audi, Mercedes Benz and BMW are more expensive
# - Fiat, Peugeot, Reanult and Opel are less expensive
# - Volkswagen, Ford and Seat are in between

# %% [markdown]
# ### Mean car mileage by brand.

# %%
# create a dictionary
mean_mileage = {}
for brand in top10:
    selected_rows = autos[autos['brand']==brand] 
    mileage = selected_rows['kilometer'].mean()
    mean_mileage[brand] = int(mileage)
    
mean_mileage = pd.Series(mean_mileage).sort_values(ascending = False)

# %%
brand_mileage = pd.DataFrame(mean_mileage, columns =[' mean_mileage'])
brand_mileage
# Out:
#                 mean_mileage
# audi                  145784
# bmw                   145227
# mercedes_benz         144782
# volkswagen            143615
# opel                  141920
# renault               141157
# seat                  140580
# ford                  140357
# peugeot               139641
# fiat                  137940

# %% [markdown]
# Audi cars has the highest mileage. Now we will check if the price of each brand depends on car mileage.

# %%
brand_price['mean_mileage']= brand_mileage
brand_price
# Out:
#                mean_price  mean_mileage
# bmw                  5526        145227
# audi                 5365        145784
# mercedes_benz        5062        144782
# volkswagen           3670        143615
# seat                 2929        140580
# ford                 2500        140357
# peugeot              2479        139641
# opel                 2237        141920
# fiat                 1939        137940
# renault              1820        141157

# %%
brand_price["mean_mileage"].describe()
# Out:
# count        10.000000
# mean     142100.300000
# std        2634.402992
# min      137940.000000
# 25%      140412.750000
# 50%      141538.500000
# 75%      144490.250000
# max      145784.000000
# Name: mean_mileage, dtype: float64

# %% [markdown]
# There are no drastic differences in the average mileage between the top 10 brands. All brands display a mean mileage over 110000 km, and the standard deviation of the series is below 5000 km.
# The brand with the highest average mileage is Audi (145784 km) and the one with the lowest is fiat (137940 km). The correlation between these two columns ('mean_price' and 'mean_mileage') is equal to 43% - that is considered to be a weak correlation. Then it can be concluded that these two characteristics ('mean_price' and 'mean_mileage') are weakly correlated; consequently, the changes in one column are not likely to influence the other column (and the other way around).

# %% [markdown]
# ## Conclusion
# We performed several data cleaning tasks before analyzing the dataset, such as:
#
# - removing 3 irrelevant columns (seller, offer_type, and nr_of_pictures) that added no valuable information;
# - excluding unreasonable entries in the kilometer, price and registration_year columns, which we categorized as outliers.
#
# Regarding the analysis of the data, we have determined that:
#
# - at the time of crawling, the majority of cars on sale in the eBay Kleinanzeigen platform were at least more than 5 years old;
# - most of the used cars announced in the crawled ads were sold after less than 2 weeks after publishing;
# - Among the top 10 most common brands, there were 3 luxury brands (audi, mercedes_benz and bmw, average price ~9000 dollars), middle-range brands (volkswagen and seat, average price ~5000 dollars) and cheaper brands (fiat and renault, average price ~3000 dollars);
# - Mean price of a car brand and its mean mileage are weakly correlated.
